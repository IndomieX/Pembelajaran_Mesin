# %%
#IMPORT LIBRARY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('botak.csv')

# %%
df
# Out:
#       umur jenis_kelamin       pekerjaan      provinsi          gaji  \
# 0     42.0     Laki-laki             PNS        Padang  7.864005e+06
# 1     33.0     Laki-laki  Pegawai swasta  Palangkaraya  6.492662e+06
# 2     59.0     Laki-laki       Freelance        Serang  8.086303e+06
# 3     38.0     Laki-laki  Pegawai swasta     Gorontalo  1.147321e+07
# 4     33.0     Perempuan       Freelance  Tanjungselor  1.475942e+07
# ...    ...           ...             ...           ...           ...
# 7986  31.0     Laki-laki  Pegawai swasta        Padang  2.911963e+07
# 7987  40.0     Perempuan  Pegawai swasta   Banjarmasin  8.955173e+06
# 7988  43.0     Perempuan             PNS       Mataram  4.022652e+06
# 7989  29.0     Laki-laki  Pegawai swasta        Serang  5.801753e+06
# 7990  55.0     Laki-laki  Pegawai swasta        Padang  8.518947e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# ...

# %%
#Mengecek Missing Value
df.isnull().sum()
# Out:
# umur              0
# jenis_kelamin     9
# pekerjaan        67
# provinsi          0
# gaji             23
# is_menikah        0
# is_keturunan     15
# berat            39
# tinggi            0
# sampo            57
# is_merokok        0
# pendidikan        0
# botak_prob        0
# dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["umur"], bins=30, kde=True, color="black", edgecolor="white")
plt.xlabel("Usia")
plt.ylabel("Jumlah Responden")
plt.title("Distribusi Usia Responden (Rafi Daniswara P.W)", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
gender_counts = df["jenis_kelamin"].dropna().value_counts()

plt.figure(figsize=(6, 6))
colors = ["gold", "blue"]
plt.pie(gender_counts, labels=gender_counts.index, autopct="%.2f%%", colors=colors, startangle=90)
plt.title("Proporsi Jenis Kelamin Responden (Rafi Daniswara P.W)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["gaji"], y=df["botak_prob"], alpha=0.6, color="blue", s=50)
plt.xlabel("Pendapatan")
plt.ylabel("Peluang Kebotakan")
plt.title("Korelasi antara Pendapatan dan Peluang Kebotakan (Rafi Daniswara P.W)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()
